# %%
import random
import math

# %%
def shellsort(elems):
    sorted_elems = elems.copy()
    gaps = [701, 301, 132, 57, 23, 10, 4, 1]
    for gap in gaps:
        for i in range(gap, len(sorted_elems)):
            temp = sorted_elems[i]
            j = i
            while j >= gap and sorted_elems[j - gap] > temp:
                sorted_elems[j] = sorted_elems[j - gap]
                j -= gap
            sorted_elems[j] = temp

    return sorted_elems

# %%
shellsort([3, 1, 2, -8, 5, -3, 4])
# Out:
# [-8, -3, 1, 2, 3, 4, 5]

# %%
def testsort(x):
    print(f'testing {len(x)}')
    assert shellsort(x) == sorted(x)

# %%
sorted([-2, 4, 2])
# Out:
# [-2, 2, 4]

# %%
testsort([-2, 2, 1])
# Out:
# testing 3

# %%
for i in range(1000):
    l = random.randint(0, 1000)
    testsort([random.randint(0, 100000) for _ in range(l)])
# Out:
# testing 854
# testing 920
# testing 251
# testing 843
# testing 78
# testing 161
# testing 985
# testing 669
# testing 330
# testing 126
# testing 612
# testing 24
# testing 683
# testing 556
# testing 728
# testing 983
# testing 283
# testing 437
# testing 495
# testing 172
# testing 967
# testing 358
# testing 952
# testing 250
# testing 533
# testing 802
# testing 816
# testing 81
# testing 604
# testing 638
# testing 181
# testing 958
# testing 53
# testing 198
# testing 907
# testing 109
# testing 877
# testing 718
# testing 390
# testing 809
# testing 488
# testing 628
# testing 479
# testing 244
# testing 152
# testing 403
# testing 811
# testing 298
# testing 286
# testing 273
# testing 717
# testing 46
# testing 551
# testing 134
# testing 335
# testing 97
# testing 469
# testing 452
# testing 425
# testing 956
# testing 333
# testing 979
# testing 59
# testing 175
# testing 902
# testing 847
# testing 981
# testing 537
# testing 728
# testing 600
# testing 978
# ...

# %%
def quadratic_solver(a, b, c):
    q = b * b - 4 * a * c
    if a == 0 or q < 0:
        return None
    solution_1 = (-b + math.sqrt(q)) / (2 * a)
    solution_2 = (-b - math.sqrt(q)) / (2 * a)
    return (solution_1, solution_2)

# %%
quadratic_solver(1, 2, -3)
# Out:
# (1.0, -3.0)
